# %% [markdown]
# # Scraping Nigerian Movies Data From Wikipedia (1992 - 2023)

# %% [markdown]
# ## Import Libraries for Extraction

# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ## Extract Data for 2015

# %%
# Attributes to Extract
year = []
title = []
director = []
cast = []
genre = []

# Define the URL
df15_link = "https://en.wikipedia.org/wiki/List_of_Nigerian_films_of_2015"

# Send an HTTP GET request to the URL
response = requests.get(df15_link)

# Parse the HTML content of the page using BeautifulSoup
soup = BeautifulSoup(response.content, "html.parser")

# Find the table(s) you want to extract
# You may need to inspect the HTML source to find the correct table
tables = soup.find_all("table", {"class": "wikitable"})

# Iterate through each table
for table in tables:
    # Iterate through the rows of the table
    for row in table.find_all('tr')[1:]:  # Skip the header row
        columns = row.find_all('td')
        if len(columns) >= 4:  # Make sure the row has enough columns
            # Extract data and append to respective lists
            title.append(columns[2].text.strip())
            director.append(columns[3].text.strip())
            cast.append(columns[4].text.strip())
            genre.append(columns[5].text.strip())

            # Create a DataFrame
df_2015 = pd.DataFrame({
    "Title": title,
    "Director": director,
    "Cast": cast,
    "Genre": genre
})

# Add the "Year" column with the year "2015" for all rows
df_2015.insert(0, "Year", 2015)

df_2015.head(10)
# Out:
#    Year                                              Title  \
# 0  2015                                      Gone Too Far!
# 1  2015                               Remi Vaughn Richards
# 2  2015                                     The Green Eyed
# 3  2015                           Darasen Richards  DJ Tee
# 4  2015  Bimbo ManuelFunlola Aofiyebi-RaimiSika Osei Ma...
# 5  2015                                       Tunde Kelani
# 6  2015                              Uche JomboChet Anekwe
# 7  2015                                       Obi Emelonye
# 8  2015                                 Michael Uadiale Jr
# 9  2015                                         The Duplex
#
#                                             Director  \
# 0                                   Destiny Ekaragha
# 1  Majid MichelOC UkejeDesmond ElliotJide KosokoO...
# 2                                 Blessing O. Oduefe
# 3  Olu JacobsBimbo AkintolaGabriel Afolayan  Rica...
# 4                                              Drama
# 5  Kemi "Lala" AkindojuSeun AkindeleKunle Afolaya...
# 6                                              Drama
# 7                Ramsey NouahMercy JohnsonMary Njoku
# 8                           Jackie AppiahBobby Obodo
# 9                                   Ikechukwu Onyeka
#
#                                                 Cast  \
# 0  OC UkejeAdelayo AdedayoShanika Warren-Markland...
# 1                                  Romantic thriller
# 2  Nse Ikpe EtimKalu IkeagwuTamara Eteimo  Blosso...
# 3                                              Drama
# 4                                Sparrow Productions
# 5                                              Drama
# 6
# 7                                              Drama
# 8                                              Drama
# 9                   Omoni OboliMike EzuruonyeUru Eke
#
#                                                Genre
# 0                                             Comedy
# 1  InkBlot Productions  Closer Pictures  FilmOne ...
# 2                                              Drama
# 3                             Darasen Richards Films
# 4                                             [3][4]
# 5                                    Mainframe Films
# 6                                                [6]
# 7                              The Nollywood Factory
# 8                                          GenMeMoir
# 9                              Supernatural Thriller

# %% [markdown]
# ## Extract Data for 1992

# %%
# Define the URL
link = "https://en.wikipedia.org/wiki/List_of_Nigerian_films_of_1992"

df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

df = pd.concat([df1, df2, df3, df3], ignore_index=True)

# Create a DataFrame
df_1992 = df[['Title','Director','Cast','Genre']]

# Add the "Year" column with the year "1992" for all rows
df_1992.insert(0, "Year", 1992)

df_1992 = df_1992.iloc[1:]

# Reset the index to start from 0
df_1992.reset_index(drop=True, inplace=True)

df_1992.head(10)
# Out:
#    Year                Title        Director  \
# 0  1992  Living in Bondage 1  Chris Obi Rapu
# 1  1992             Agba Man    Moses Olaiya
# 2  1992                  NaN             NaN
# 3  1992                  NaN             NaN
# 4  1992                  NaN             NaN
# 5  1992                  NaN             NaN
# 6  1992                  NaN             NaN
# 7  1992                  NaN             NaN
# 8  1992                  NaN             NaN
# 9  1992                  NaN             NaN
#
#                                                 Cast             Genre
# 0  Kanayo O. Kanayo Kenneth Okonkwo Okechukwu Ogu...  Drama / thriller
# 1  Moses Olaiya Shola Shoremekun Bankole Ayodeji ...               NaN
# 2                                                NaN               NaN
# 3                                                NaN               NaN
# 4                                                NaN               NaN
# 5                                                NaN               NaN
# 6                                                NaN               NaN
# 7                                                NaN               NaN
# 8                                                NaN               NaN
# 9                                                NaN               NaN

# %% [markdown]
# ## Extract Data for 1997

# %%
# Define the URL
link = "https://en.wikipedia.org/wiki/List_of_Nigerian_films_of_1997"

df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

df = pd.concat([df1, df2, df3, df3], ignore_index=True)

# Create a Dataframe
df_1997 = df[['Title','Director','Cast','Genre']]

# Add the "Year" column with the year "1997" for all rows
df_1997.insert(0, "Year", 1997)

df_1997 = df_1997.iloc[1:]

# Reset the index to start from 0
df_1997.reset_index(drop=True, inplace=True)

df_1997.head(10)
# Out:
#    Year                                              Title           Director  \
# 0  1997                                     Back to Africa         Tony Abulu
# 1  1997                                        Blood Money        Chico Ejiro
# 2  1997                           Crossroad: The Beginning  Christyn Michaels
# 3  1997                                         Dead End 2        Chico Ejiro
# 4  1997                                      Died Wretched     Kenneth Nnebue
# 5  1997       Flesh and Blood: The Jessie Chukwuma Story 2        Chico Ejiro
# 6  1997                                            Forever         Amaka Igwe
# 7  1997                                           Hostages        Tade Ogidan
# 8  1997  Iya Ibeji Eleran Igbe (Mother of Twins, Seller...        Abbey Lanre
# 9  1997                               Obe Gbona (Hot Soup)                NaN
#
#                                                 Cast   Genre
# 0    Wole Amele Ella Asad Jimmy Johnson Lanre Hassan     NaN
# 1    Zack Orji Kanayo O. Kanayo Francis Agu Sam Dede     NaN
# 2  Gbenga Richards Ngozi Nwosu Emeka Ossai Kate H...     NaN
# 3  Zack Orji Liz Benson Sandra Achums Ameze Imari...     NaN
# 4  Tony Umez Eucharia Anunobi Rachel Oniga Tom Nj...     NaN
# 5  Ameze Imarhiagbe Richard Mofe-Damijo Bassey-In...     NaN
# 6  Justus Esiri Hilda Dokubo John Nwaobi Ohi Aleg...     NaN
# 7  Tope Idowu Ofuafo Otomewo Richard Mofe Damijo ...  Action
# 8  Aduke Adeyemo Gbolagade Akinpelu Dupe Johnson ...     NaN
# 9  Moses Olaiya Adejumo Iya Sala Adisa Baba Oyin ...     NaN

# %% [markdown]
# ## Extract Data for 1998

# %%
# Define the URL
link = "https://en.wikipedia.org/wiki/List_of_Nigerian_films_of_1998"

df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

df = pd.concat([df1, df2, df3, df3], ignore_index=True)

# Create a Dataframe
df_1998 = df[['Title','Director','Cast','Genre']]

# Add the "Year" column with the year "1998" for all rows
df_1998.insert(0, "Year", 1998)

df_1998 = df_1998.iloc[1:]

# Reset the index to start from 0
df_1998.reset_index(drop=True, inplace=True)

df_1998.head(10)
# Out:
#    Year             Title           Director  \
# 0  1998      Diamond Ring        Tade Ogidan
# 1  1998            Sakobi          Zeb Ejiro
# 2  1998            Amadas      Andy Amenechi
# 3  1998   Suicide Mission         Fred Amata
# 4  1998            Oracle      Andy Amenechi
# 5  1998  Scores to Settle        Chico Ejiro
# 6  1998      Yogo Pam Pam     Kingsley Ogoro
# 7  1998       Most Wanted  Tunji Bamishigbin
# 8  1998               NaN                NaN
# 9  1998               NaN                NaN
#
#                                                 Cast         Genre
# 0  Liz Benson Richard Mofe-Damijo Bimbo Akintola ...        Horror
# 1  Saint Obi Susan Patrick Tony Umez Edith Ujay S...           NaN
# 2  Enebeli Elebuwa Saint Obi Bimbo Akintola Adaor...           NaN
# 3  Richard Mofe-Damijo Regina Askia Ameze Imarhia...           NaN
# 4  Pete Edochie Prince James Uche Enebeli Elebuwa...           NaN
# 5  Richard Mofe Damijo Liz Benson Omotola Jalade ...           NaN
# 6                              Nkem Owoh Okey Bakasi           NaN
# 7  Regina Askia Ibinabo Fiberisima Ayo Adesanya L...  Crime action
# 8                                                NaN           NaN
# 9                                                NaN           NaN

# %% [markdown]
# ## Extract Data for 2001

# %%
# Define the URL
link = "https://en.wikipedia.org/wiki/List_of_Nigerian_films_of_2001"

df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

df = pd.concat([df1, df2, df3, df3], ignore_index=True)

# Create a Dataframe
df_2001 = df[['Title','Director','Cast','Genre']]

# Add the "Year" column with the year "2001" for all rows
df_2001.insert(0, "Year", 2001)

df_2001 = df_2001.iloc[1:]

# Reset the index to start from 0
df_2001.reset_index(drop=True, inplace=True)

df_2001.head(10)
# Out:
#    Year                                Title          Director  \
# 0  2001                 Girls Hostel 1 and 2     Ndubuisi Okoh
# 1  2001                     Holy Law: Sharia     Ejike Asiegbu
# 2  2001                         Last Prophet  Lancelot Imasuen
# 3  2001                  Oil Village 1 and 2         Kalu Anya
# 4  2001  Okuzu Massacre: The Robbers Revenge         John Evah
# 5  2001                              Outkast       Chico Ejiro
# 6  2001                                  NaN               NaN
# 7  2001                                  NaN               NaN
# 8  2001                                  NaN               NaN
# 9  2001                                  NaN               NaN
#
#                                                 Cast     Genre
# 0  Olu Jacobs Empress Njamah Alexandra Lopez Uche...       NaN
# 1  Alex Usifo Ejike Asiegbu Ibrahim Mandawari Rac...       NaN
# 2  Zulu Adigwe Ejike Asiegbu Franca Brown Larry K...       NaN
# 3  Sam Loco Efe Sam Obiekheme Sandra Achums Nnamd...       NaN
# 4  Segun Arinze Hanks Anuku Amaechi Muonagor Gent...       NaN
# 5                          Sandra Achums Lilian Bach  Thriller
# 6                                                NaN       NaN
# 7                                                NaN       NaN
# 8                                                NaN       NaN
# 9                                                NaN       NaN

# %% [markdown]
# ## Extract Data for 2002

# %%
# Define the URL
link = "https://en.wikipedia.org/wiki/List_of_Nigerian_films_of_2002"

df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

df = pd.concat([df1, df2, df3, df3], ignore_index=True)

# Create a Dataframe
df_2002 = df[['Title','Director','Cast','Genre']]

# Add the "Year" column with the year "2002" for all rows
df_2002.insert(0, "Year", 2002)

df_2002 = df_2002.iloc[1:]

# Reset the index to start from 0
df_2002.reset_index(drop=True, inplace=True)

df_2002.head(10)
# Out:
#    Year             Title           Director  \
# 0  2002       Aki na Ukwa  Amayo Uzo Philips
# 1  2002  Formidable Force        Teco Benson
# 2  2002         Okada Man     Tchidi Chikere
# 3  2002     The Last Vote      Andy Amenechi
# 4  2002               NaN                NaN
# 5  2002               NaN                NaN
# 6  2002               NaN                NaN
# 7  2002               NaN                NaN
# 8  2002               NaN                NaN
# 9  2002               NaN                NaN
#
#                                                 Cast   Genre
# 0                       Osita Iheme Chinedu Ikedieze  Comedy
# 1  Hanks Anuku Ernest Asuzu George Davidson Genev...     NaN
# 2  Nkem Owoh Patience Ozokwor Pete Eneh David Ihesie     NaN
# 3      Sam Dede Olu Jacobs Acho Ugenyi Sandra Achums     NaN
# 4                                                NaN     NaN
# 5                                                NaN     NaN
# 6                                                NaN     NaN
# 7                                                NaN     NaN
# 8                                                NaN     NaN
# 9                                                NaN     NaN

# %% [markdown]
# ## Extract Data for 2003

# %%
# Define the URL
link = "https://en.wikipedia.org/wiki/List_of_Nigerian_films_of_2003"

df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

df = pd.concat([df1, df2, df3, df3], ignore_index=True)

# Create a Dataframe
df_2003 = df[['Title','Director','Cast','Genre']]

# Add the "Year" column with the year "2003" for all rows
df_2003.insert(0, "Year", 2003)

df_2003 = df_2003.iloc[1:]

# Reset the index to start from 0
df_2003.reset_index(drop=True, inplace=True)

df_2003.head(10)
# Out:
#    Year                         Title           Director  \
# 0  2003                        2 Rats        Andy Chukwu
# 1  2003  Above Death: In God We Trust      Simi Opeoluwa
# 2  2003              Abuja Connection      Adim Williams
# 3  2003                   Baby Police  Amayo Uzo Philips
# 4  2003               Emotional Crack   Lancelot Imasuen
# 5  2003  Kasalama: The Slave Merchant     Kenneth Egbuna
# 6  2003             Mission To Africa        Joy Dickson
# 7  2003                     Oil Money      Neville Ossai
# 8  2003             Osuofia in London     Kingsley Ogoro
# 9  2003                           NaN                NaN
#
#                                                 Cast  \
# 0                       Osita Iheme Chinedu Ikedieze
# 1  Pete Edochie Kate Henshaw-Nuttal Genevieve Nna...
# 2                                                NaN
# 3  Ijeoma Angel Boniface Okey Billy Boniface Osit...
# 4  Ramsey Nouah Dakore Egbuson Stephanie Okereke ...
# 5  Sam Loco Efe Chiwetalu Agu Tom Njemanze Emeka Ani
# 6    Olu Jacobs Segun Arinze Gloria Anozie Bruno Jnr
# 7  Clem Ohameze Chidi Mokeme Chijioke Abagwe Maur...
# 8                                          Nkem Owoh
# 9                                                NaN
#
#                        Genre
# 0                     Comedy
# 1                      Drama
# 2  Action / drama / thriller
# 3             Comedy / drama
# 4                        NaN
# 5                        NaN
# 6           Thriller / drama
# 7                        NaN
# 8                     Comedy
# 9                        NaN

# %% [markdown]
# ## Extract Data for 2004

# %%
# Define the URL
link = "https://en.wikipedia.org/wiki/List_of_Nigerian_films_of_2004"

df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

df = pd.concat([df1, df2, df3, df3], ignore_index=True)

# Create a Dataframe
df_2004 = df[['Title','Director','Cast','Genre']]

# Add the "Year" column with the year "2004" for all rows
df_2004.insert(0, "Year", 2004)

df_2004 = df_2004.iloc[1:]

# Reset the index to start from 0
df_2004.reset_index(drop=True, inplace=True)

df_2004.head(10)
# Out:
#    Year                       Title          Director  \
# 0  2004                Fateful Love     Simi Opeoluwa
# 1  2004    Goodbye New York 1 and 2    Tchidi Chikere
# 2  2004             Home and Abroad  Lancelot Imasuen
# 3  2004  Last Girl Standing 1 and 2         John Uche
# 4  2004               Missing Angel     Charles Novia
# 5  2004                  The Mayors   Dickson Iroegbu
# 6  2004              The London Boy     Simi Opeoluwa
# 7  2004              London Forever       Chico Ejiro
# 8  2004            Mr Ibu in London     Adim Williams
# 9  2004                         NaN               NaN
#
#                                                 Cast  Genre
# 0  Ramsey Nouah Omotola Jalade Ekeinde Paul Obaze...    NaN
# 1  Genevieve Nnaji Jim lyke Rita Dominic Chidi Mo...    NaN
# 2  John Okafor Victor Oswuagwu Izoya Isaac Rita A...    NaN
# 3  Jim Iyke Stepahnie Okereke Robert Peters Empre...    NaN
# 4             Stella Damasus Aboderin Desmond Elliot  Drama
# 5          Richard Mofe-Damijo Sam Dede Segun Arinze  Drama
# 6  Ramsey Nouah Simone McIntyre Segun Arinze Uche...    NaN
# 7  Shan George Lanre Falana Lilian Bach Rachel Oniga    NaN
# 8  John Okafor Ishola Oshun Kareem Adepoju Femi F...    NaN
# 9                                                NaN    NaN

# %% [markdown]
# ## Extract Data for 2005

# %%
# Define the URL
link = "https://en.wikipedia.org/wiki/List_of_Nigerian_films_of_2005"

df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

df = pd.concat([df1, df2, df3, df3], ignore_index=True)

# Create a Dataframe
df_2005 = df[['Title','Director','Cast','Genre']]

# Add the "Year" column with the year "2005" for all rows
df_2005.insert(0, "Year", 2005)

df_2005 = df_2005.iloc[1:]

# Reset the index to start from 0
df_2005.reset_index(drop=True, inplace=True)

df_2005.head(10)
# Out:
#    Year        Title       Director  \
# 0  2005  Rising Moon  Andy Nwakolor
# 1  2005          NaN            NaN
# 2  2005          NaN            NaN
# 3  2005          NaN            NaN
# 4  2005          NaN            NaN
# 5  2005          NaN            NaN
# 6  2005          NaN            NaN
# 7  2005          NaN            NaN
# 8  2005          NaN            NaN
# 9  2005          NaN            NaN
#
#                                                 Cast  Genre
# 0  Akume Akume, Arthur Brooks, Justus Esiri, Onye...  Drama
# 1                                                NaN    NaN
# 2                                                NaN    NaN
# 3                                                NaN    NaN
# 4                                                NaN    NaN
# 5                                                NaN    NaN
# 6                                                NaN    NaN
# 7                                                NaN    NaN
# 8                                                NaN    NaN
# 9                                                NaN    NaN

# %% [markdown]
# ## Extract Data for 2006

# %%
# Define the URL
link = "https://en.wikipedia.org/wiki/List_of_Nigerian_films_of_2006"

df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

df = pd.concat([df1, df2, df3, df3], ignore_index=True)

# Create a Dataframe
df_2006 = df[['Title','Director','Cast','Genre']]

# Add the "Year" column with the year "2006" for all rows
df_2006.insert(0, "Year", 2006)

df_2006 = df_2006.iloc[1:]

# Reset the index to start from 0
df_2006.reset_index(drop=True, inplace=True)

df_2006.head(10)
# Out:
#    Year                             Title                Director  \
# 0  2006                           30 Days            Mildred Okwo
# 1  2006                             Abeni                     NaN
# 2  2006                    Games Men Play  Lancelot Oduwa Imasuen
# 3  2006               Girls Cot 1-3. 2006            Afam Okereke
# 4  2006                             Manko   Alhaji Sagir Mohammed
# 5  2006                       Mr Lecturer        Prince Emeka Ani
# 6  2006  Night in the Philippines 1 and 2               Zeb Ejiro
# 7  2006                           Sitanda              Izu Ojukwu
# 8  2006                 The Amazing Grace              Jeta Amata
# 9  2006                   The Narrow Path            Tunde Kelani
#
#                                                 Cast              Genre
# 0            Genevieve Nnaji Joke Silva Segun Arinze  Action / thriller
# 1                                                NaN                NaN
# 2  Kate Henshaw-Nuttal Ini Edo Chioma Chukwuka Ch...                NaN
# 3    Genevieve Nnaji Rita Dominic Ini Edo Uche Jombo                NaN
# 4  Yahaya Alfa Abdullahi Mohamed Bida John Gana M...                NaN
# 5  Nkem Owoh Sam Loco Efe Stella Ikwuegbu Chidinm...                NaN
# 6  Desmond Elliot Ibinabo Fiberesima Marie Eboka ...                NaN
# 7                                  Stephanie Okereke  Adventure / drama
# 8              Joke Silva Nick Moran Scott Cleverdon                NaN
# 9  Sola Asedeko Seyi Fasuyi Eniola Olaniyan Ayo B...                NaN

# %% [markdown]
# ## Extract Data for 2007

# %%
# Define the URL
link = "https://en.wikipedia.org/wiki/List_of_Nigerian_films_of_2007"

df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

df = pd.concat([df1, df2, df3, df3], ignore_index=True)

# Create a Dataframe
df_2007 = df[['Title','Director','Cast','Genre']]

# Add the "Year" column with the year "2007" for all rows
df_2007.insert(0, "Year", 2007)

df_2007 = df_2007.iloc[1:]

# Reset the index to start from 0
df_2007.reset_index(drop=True, inplace=True)

df_2007.head(10)
# Out:
#    Year                                            Title  \
# 0  2007                                             Ezra
# 1  2007  Europe by Road.. Miles Away from Africa 1 and 2
# 2  2007                               Final Hour 1 and 2
# 3  2007                             Irapada (Redemption)
# 4  2007                            Letters to a Stranger
# 5  2007                                     Last Messiah
# 6  2007                 Life Incidence: A Day to Destiny
# 7  2007                                Made in Cambridge
# 8  2007                                      The Faculty
# 9  2007                                              NaN
#
#                       Director  \
# 0             Newton I. Aduaka
# 1               Ikenna Ezeugwu
# 2                 Afam Okereke
# 3  Kunle Afolayan Biodun Aleja
# 4                   Fred Amata
# 5                  Moses Ebere
# 6                   Iyke Odife
# 7          Mac-Collins Chidebe
# 8                    Ugo Ugbor
# 9                          NaN
#
#                                                 Cast            Genre
# 0                               Mamoudu Turay Kamara            Drama
# 1  Kevin Bucks Leo Chimmezie Chris Onyenso Rahim Kas              NaN
# 2       Oge Okoye Nonso Diobi Uche Jombo Tonto Dikeh              NaN
# 3  Kunle Afolayan Deola Oloyede Jotham Ayuba Ange...              NaN
# 4               Genevieve Nnaji Joke Silva Yemi Blaq  Romantic comedy
# 5     Nkem Owoh Fabian Adibe Roy Denani Miriam Apolo              NaN
# 6  Jim Iyke Mike Ezuruonye Ebube Nwagbo Browny Ig...              NaN
# 7  Nkem Owoh Louisa Nwobodo Funmi Holder Gardiel ...              NaN
# 8  Ramsey Nouah Jim Iyke Oge Okoye McMorris Ndubueze              NaN
# 9                                                NaN              NaN

# %% [markdown]
# ## Extract Data for 2008

# %%
# Define the URL
link = "https://en.wikipedia.org/wiki/List_of_Nigerian_films_of_2008"

df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

df = pd.concat([df1, df2, df3, df3], ignore_index=True)

# Create a Dataframe
df_2008 = df[['Title','Director','Cast','Genre']]

# Add the "Year" column with the year "2008" for all rows
df_2008.insert(0, "Year", 2008)

df_2008 = df_2008.iloc[1:]

# Reset the index to start from 0
df_2008.reset_index(drop=True, inplace=True)

df_2008.head(10)
# Out:
#    Year                  Title             Director  \
# 0  2008  Hottest Babes 1 and 2       Emeka Nwabueze
# 1  2008         Jenifa 1 and 2   Muhydeen S. Ayinde
# 2  2008      Liquid Black Gold  Ikenna Emma Aniekwe
# 3  2008      Through the Glass    Stephanie Okereke
# 4  2008                    NaN                  NaN
# 5  2008                    NaN                  NaN
# 6  2008                    NaN                  NaN
# 7  2008                    NaN                  NaN
# 8  2008                    NaN                  NaN
# 9  2008                    NaN                  NaN
#
#                                                 Cast   Genre
# 0        Oge Okoye Francis Duru Chika Ike Uche Jombo     NaN
# 1  Funke Akindele Ronke Odusanya Mosunmola Filani...  Comedy
# 2  Sam Dede Justus Esiri Enebeli Elebuwa Gentle Jack     NaN
# 3                     Stephanie Okereke Pascal Atuma  Comedy
# 4                                                NaN     NaN
# 5                                                NaN     NaN
# 6                                                NaN     NaN
# 7                                                NaN     NaN
# 8                                                NaN     NaN
# 9                                                NaN     NaN

# %% [markdown]
# ## Extract Data for 2009

# %%
# Define the URL
link = "https://en.wikipedia.org/wiki/List_of_Nigerian_films_of_2009"

df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

df = pd.concat([df1, df2, df3, df3], ignore_index=True)

# Create a Dataframe
df_2009 = df[['Title','Director','Cast','Genre']]

# Add the "Year" column with the year "2009" for all rows
df_2009.insert(0, "Year", 2009)

df_2009 = df_2009.iloc[1:]

# Reset the index to start from 0
df_2009.reset_index(drop=True, inplace=True)

df_2009.head(10)
# Out:
#    Year                     Title                  Director  \
# 0  2009           Forbidden Fruit         Frank Rajah Arase
# 1  2009          Guilty Pleasures            Desmond Elliot
# 2  2009       Naked Girls 1 and 2             Cyril Jackson
# 3  2009    Nigerian Girls 1 and 2  Dandy Chukwuemeka Echefu
# 4  2009                  Reloaded    Lancelot Oduwa Imasuen
# 5  2009  The Figurine (Araromire)            Kunle Afolayan
# 6  2009                       NaN                       NaN
# 7  2009                       NaN                       NaN
# 8  2009                       NaN                       NaN
# 9  2009                       NaN                       NaN
#
#                                                 Cast           Genre
# 0  John Dumelo Majid Michel Jackie Appiah Yvonne ...             NaN
# 1  Ramsey Nouah Majid Michel Nse Ikpe Etim Mercy ...             NaN
# 2  Vincent Opurum Sean Blessed Tonto Dike Enebeli...             NaN
# 3  Uche Elendu Emeka Enyiocha McMorris Ndubueze U...             NaN
# 4  Ramsey Nouah Stephanie Okereke Uche Jombo Van ...  Romantic drama
# 5  Kunle Afolayan Ramsey Nouah Omoni Oboli Funlol...        Thriller
# 6                                                NaN             NaN
# 7                                                NaN             NaN
# 8                                                NaN             NaN
# 9                                                NaN             NaN

# %% [markdown]
# ## Extract Data for 2010

# %%
# Define the URL
link = "https://en.wikipedia.org/wiki/List_of_Nigerian_films_of_2010"

df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

df = pd.concat([df1, df2, df3, df3], ignore_index=True)

# Create a Dataframe
df_2010 = df[['Title','Director','Cast','Genre']]

# Add the "Year" column with the year "2010" for all rows
df_2010.insert(0, "Year", 2010)

df_2010 = df_2010.iloc[1:]

# Reset the index to start from 0
df_2010.reset_index(drop=True, inplace=True)

df_2010.head(10)
# Out:
#    Year                     Title          Director  \
# 0  2010               Anchor Baby      Lonzo Nzekwe
# 1  2010                   Aramotu       Niji Akanni
# 2  2010  Between Kings and Queens       Joy Dickson
# 3  2010     Braids on a Bald Head       Ishaya Bako
# 4  2010              Bursting Out    Desmond Elliot
# 5  2010   Good Girls Gone Bad 1-4  Nonso Emekaekwue
# 6  2010              Holding Hope    Desmond Elliot
# 7  2010          Ijé, the Journey   Chineze Anyaene
# 8  2010                     Inale        Jeta Amata
# 9  2010               Men in Love       John Dumelo
#
#                                                 Cast             Genre
# 0               Omoni Oboli Sam Sarpong Terri Oliver  Drama / thriller
# 1  Idiat Sobande Kayode Odumosu Ireti Osayemi-Bak...             Drama
# 2              Jim Iyke Nakia Burrise DaJuan Johnson  Romance / Action
# 3                                                NaN             Drama
# 4  Genevieve Nnaji Majid Michel Desmond Elliot Su...             Drama
# 5   Oge Okoye Nonso Diobi Chika Ike Halimah Abubakar               NaN
# 6              Nadia Buari Uche Jombo Desmond Elliot             Drama
# 7  Genevieve Nnaji Odalys García Omotola Jalade-E...             Drama
# 8  Caroline ChikezieHakeem Kae-KazimNse Ikpe Etim...               NaN
# 9            Tonto Dike Muna Obiekwe Halima Abubakar             Drama

# %% [markdown]
# ## Extract Data for 2011

# %%
# Define the URL
link = "https://en.wikipedia.org/wiki/List_of_Nigerian_films_of_2011"

df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

df = pd.concat([df1, df2, df3, df3], ignore_index=True)

# Create a Dataframe
df_2011 = df[['Title','Director','Cast','Genre']]

# Add the "Year" column with the year "2011" for all rows
df_2011.insert(0, "Year", 2011)

df_2011.head(10)
# Out:
#    Year                  Title        Director  \
# 0  2011      Ibu in Campus 1-4  Charles Inojie
# 1  2011                Nkwocha      Stan Amadi
# 2  2011         The Mirror Boy    Obi Emelonye
# 3  2011  Two Brides and a Baby     Teco Benson
# 4  2011   I'll Take My Chances  Desmond Elliot
# 5  2011                    NaN             NaN
# 6  2011                    NaN             NaN
# 7  2011                    NaN             NaN
# 8  2011                    NaN             NaN
# 9  2011                    NaN             NaN
#
#                                                 Cast  \
# 0  John Okafor Charles Inojie Okey Bakassi Cynthi...
# 1      Chiwetalu AguQueen NwaokoyeUche Elendu Walter
# 2  Genevieve Nnaji Osita Iheme Edward Kagutuzi Fa...
# 3  OC Ukeje Stella Damasus-Aboderin Kalu Ikeagwu ...
# 4      Ini Edo Bryan Okwara Sam Loco Efe Jide Kosoko
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#                          Genre
# 0                          NaN
# 1                          NaN
# 2  Drama / fantasy / adventure
# 3               Romantic drama
# 4       Dance / romantic drama
# 5                          NaN
# 6                          NaN
# 7                          NaN
# 8                          NaN
# 9                          NaN

# %% [markdown]
# ## Extract Data for 2012

# %%
# Define the URL
link = "https://en.wikipedia.org/wiki/List_of_Nigerian_films_of_2012"

df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

df = pd.concat([df1, df2, df3, df3], ignore_index=True)

# Create a Dataframe
df_2012 = df[['Title','Director','Cast','Genre']]

# Add the "Year" column with the year "2012" for all rows
df_2012.insert(0, "Year", 2012)

df_2012.head(10)
# Out:
#    Year                 Title                Director  \
# 0  2012            Phone Swap          Kunle Afolayan
# 1  2012       Journey to Self         Tope Oshin Ogun
# 2  2012               Adesuwa  Lancelot Oduwa Imasuen
# 3  2012  Last Flight to Abuja            Obi Emelonye
# 4  2012      Fuelling Poverty             Ishaya Bako
# 5  2012         Turning Point           Niyi Towolawi
# 6  2012       Weekend Getaway          Desmond Elliot
# 7  2012           The Meeting            Mildred Okwo
# 8  2012              Hoodrush          Dimeji Ajibola
# 9  2012                 Amina       Christian Ashaiku
#
#                                                 Cast                Genre
# 0        Nse Ikpe EtimWale OjoLydia ForsonJoke Silva      Romantic comedy
# 1  Nse Ikpe EtimDakore AkandeKatherine ObiangTosi...                  NaN
# 2  Olu JacobsBob-Manuel UdokwuNgozi EzeonuKofi Ad...                  NaN
# 3     Omotola Jalade EkeindeHakeem Kae-KazimJim Iyke  Disaster / thriller
# 4                                                NaN          Documentary
# 5  Jackie Appiah K.D. AubertErnie HudsonTodd Brid...                Drama
# 6  Genevieve Nnaji Uti NwachukwuIni EdoRamsey Nou...       Romantic drama
# 7  Rita Dominic Femi JacobsLinda EjioforJide Koso...       Romantic drama
# 8  OC Ukeje Bimbo AkintolaGabriel AfolayanChelsea...     Musical thriller
# 9  OC Ukeje Omotola Jalade EkeindeWil JohnsonVan ...  Psychological drama

# %% [markdown]
# ## Extract Data for 2013

# %%
# Define the URL
link = "https://en.wikipedia.org/wiki/List_of_Nigerian_films_of_2013"

df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

df = pd.concat([df1, df2, df3, df3], ignore_index=True)

# Create a Dataframe
df_2013 = df[['Title','Director','Cast','Genre']]

# Add the "Year" column with the year "2013" for all rows
df_2013.insert(0, "Year", 2013)

df_2013.head(10)
# Out:
#    Year                   Title                  Director  \
# 0  2013         Forgetting June          Ikechukwu Onyeka
# 1  2013                  Broken       Bright Wonder Obasi
# 2  2013  Murder at Prime Suites        Eneaji Chris Eneng
# 3  2013                    Torn              Moses Inwang
# 4  2013        A Mile from Home             Eric Aghimien
# 5  2013               Awakening  James OmokweEthan Okwara
# 6  2013    Half of a Yellow Sun              Biyi Bandele
# 7  2013             Secret Room        Eneaji Chris Eneng
# 8  2013               B for Boy               Chika Anadu
# 9  2013                Accident               Teco Benson
#
#                                                 Cast                   Genre
# 0  Majid MichelBeverly NayaMbong Amata Blossom Ch...          Romantic drama
# 1              Nse Ikpe EtimBimbo ManuelKalu Ikeagwu                   Drama
# 2  Joseph BenjaminChelsea EzeKeira Hewatch Okey U...        Crime / thriller
# 3  Monalisa ChindaIreti DoyleJoseph Benjamin Tope...  Psychological thriller
# 4  Tope TedelaChiedozie 'Sambasa' NzeribeAlex Aya...          Romantic drama
# 5    OC UkejeKehinde BankoleFemi BrainardTope Tedela           Dark thriller
# 6  Chiwetel EjioforThandie NewtonGenevieve NnajiO...        Historical drama
# 7      OC UkejeJide KosokoLinda Ejiofor Lilian Esoro                Thriller
# 8              Uche NwadiliNgozi NwanetoNonso Odogwu                     NaN
# 9       Chioma ChukwukaKalu IkeagwuFrederick Leonard                Thriller

# %% [markdown]
# ## Extract Data for 2014

# %%
# Define the URL
link = "https://en.wikipedia.org/wiki/List_of_Nigerian_films_of_2014"

df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

df = pd.concat([df1, df2, df3, df3], ignore_index=True)

# Create a Dataframe
df_2014 = df[['Title','Director','Cast','Genre']]

# Add the "Year" column with the year "2014" for all rows
df_2014.insert(0, "Year", 2014)

df_2014.head(10)
# Out:
#    Year                      Title                          Director  \
# 0  2014           Being Mrs Elliot                       Omoni Oboli
# 1  2014           Render to Caesar  Desmond Ovbiagele Onyekachi Ejim
# 2  2014                     Tunnel                 Stanlee Ohikhuare
# 3  2014                      Iyore                 Frank Rajah Arase
# 4  2014                Make a Move                  Niyi Akinmolayan
# 5  2014  Knocking on Heaven's Door                    Desmond Elliot
# 6  2014                  October 1                    Kunle Afolayan
# 7  2014           Brother's Keeper                  Ikechukwu Onyeka
# 8  2014                        Dry                 Stephanie Okereke
# 9  2014         30 Days in Atlanta                     Robert Peters
#
#                                                 Cast  \
# 0     Majid MichelOmoni OboliSylvia Oluchy Ayo Makun
# 1  Gbenga AkinnagbeOmoni OboliWale Ojo Bimbo Manu...
# 2                      Nse Ikpe Etim Femi JacobsWaje
# 3           Rita Dominic Bukky WrightJoseph Benjamin
# 4      Ivie Okujaye Tina MbaBeverly NayaWale Adebayo
# 5  Majid Michel Adesuwa Etomi Blossom Chukwujekwu...
# 6  Sadiq Daba Kehinde Bankole David BaileDeola Sagoe
# 7  Majid Michel Omoni Oboli Beverly NayaBarbara Soky
# 8  Stephanie Okereke Liz Benson William McNamaraD...
# 9  Ayo Makun Vivica A. Fox Lynn WhitfieldKarlie Redd
#
#                          Genre
# 0              Romantic comedy
# 1                  Crime drama
# 2                        Drama
# 3                        Drama
# 4              Dance / musical
# 5     Romantic drama / musical
# 6  Dark psychological thriller
# 7                     Thriller
# 8                        Drama
# 9                       Comedy

# %% [markdown]
# ## Extract Data for 2016

# %%
# Define the URL
link = "https://en.wikipedia.org/wiki/List_of_Nigerian_films_of_2016"

df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

df = pd.concat([df1, df2, df3, df3], ignore_index=True)

# Create a Dataframe
df_2016 = df[['Title','Director','Cast','Genre']]

# Add the "Year" column with the year "2016" for all rows
df_2016.insert(0, "Year", 2016)

df_2016.head(10)
# Out:
#    Year                 Title           Director  \
# 0  2016  Elephant in the Room      Asurf Oluseyi
# 1  2016          Beyond Blood       Greg Odutayo
# 2  2016   Love is in the Hair     Ansa Kpokpogri
# 3  2016        Couple of Days        Lord Tanner
# 4  2016            Suru L'ere       Mildred Okwo
# 5  2016               93 Days        Steve Gukas
# 6  2016               The CEO     Kunle Afolayan
# 7  2016         Ghana Must Go  Frank Rajah Arase
# 8  2016                   NaN                NaN
# 9  2016                   NaN                NaN
#
#                                                 Cast            Genre
# 0                         Ramsey NouahZainab Sheriff  Romantic Comedy
# 1  Kehinde BankoleJoseph Benjamin Bimbo ManuelCar...   Romantic Drama
# 2  Uti NwachukwuBishop Ime Toyin AimakhuOkey Bakassi  Romantic Comedy
# 3  Lilian EsoroKiki OmeiliAdesua Etomi Ademola Ad...  Romantic Comedy
# 4     Beverly NayaSeun AkindeleKemi Lala Tope Tedela     Comedy Drama
# 5     Bimbo AkintolaDanny GloverBimbo ManuelTim Reid       Docu-Drama
# 6     Kemi Lala AkindojuHilda DokuboJimmy Jean-Louis            Drama
# 7  Yvonne OkoroBlossom ChukwujekwuNkem OwohIk Ogb...            Drama
# 8                                                NaN              NaN
# 9                                                NaN              NaN

# %% [markdown]
# ## Extract Data for 2017

# %%
# Define the URL
link = "https://en.wikipedia.org/wiki/List_of_Nigerian_films_of_2017"

df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

df = pd.concat([df1, df2, df3, df3], ignore_index=True)

# Create a Dataframe
df_2017 = df[['Title','Director','Cast','Genre']]

# Add the "Year" column with the year "2017" for all rows
df_2017.insert(0, "Year", 2017)

df_2017.head(10)
# Out:
#    Year                     Title          Director  \
# 0  2017  The Royal Hibiscus Hotel       Ishaya Bako
# 1  2017           American Driver      Moses Inwang
# 2  2017       Sudani from Nigeria          Zakariya
# 3  2017             Sobi's Mystic    Biodun Stephen
# 4  2017                   Lotanna      Toka McBaror
# 5  2017                    Isoken  Jadesola Osiberu
# 6  2017       10 Days in Sun City         Adze Ugha
# 7  2017       Christmas Is Coming  Ufuoma McDermott
# 8  2017       The Wedding Party 2  Niyi Akinmolayan
# 9  2017       Christmas Is Coming  Ufuoma McDermott
#
#                                                 Cast  \
# 0  Zainab BalogunKenneth OkolieDeyemi OkanlawonJo...
# 1  Evan KingJim IykeNse Ikpe EtimAyo MakunEmma Ny...
# 2                Soubin ShahirSamuel Abiola Robinson
# 3               Bolaji OgunmolaKunle RemiMofe Duncan
# 4  Liz BensonVictor OlaotanChris OkagbueAma Abebrese
# 5  Dakore Akande Joseph BenjaminFunke AkindeleMar...
# 6  Ayo MakunAdesuwa EtomiRichard Mofe-DamijoMercy...
# 7  Chioma ChukwukaDeyemi OkanlawonZack OrjiMary L...
# 8  Sola Sobowale Patience Ozokwor Adesua Etomi Ba...
# 9  Chioma ChukwukaDeyemi OkanlawonZack OrjiMary L...
#
#                         Genre
# 0                 Comedy film
# 1                 Comedy film
# 2            Comedy and Drama
# 3              Romantic Drama
# 4                       Drama
# 5              Romantic Drama
# 6                Comedy Drama
# 7             Romantic comedy
# 8  romantic comedy-drama film
# 9             Romantic comedy

# %% [markdown]
# ## Extract Data for 2018

# %%
# Define the URL
link = "https://en.wikipedia.org/wiki/List_of_Nigerian_films_of_2018"

df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

df = pd.concat([df1, df2, df3, df3], ignore_index=True)

# Create a Dataframe
df_2018 = df[['Title','Director','Cast','Genre']]

# Add the "Year" column with the year "2018" for all rows
df_2018.insert(0, "Year", 2018)

df_2018.head(10)
# Out:
#    Year                              Title          Director  \
# 0  2018                          Lionheart   Genevieve Nnaji
# 1  2018                 Boss of All Bosses       Ike Nnaebue
# 2  2018                 Ghost and the Tout   Charles Uwagbai
# 3  2018                 What Just Happened   Charles Uwagbai
# 4  2018                 Sylvia (2018 film)    Daniel Orhiari
# 5  2018  Merry Men: The Real Yoruba Demons      Toka Mcbaror
# 6  2018                        Chief Daddy  Niyi Akinmolayan
# 7  2018                           Up North   Tope Oshin Ogun
# 8  2018                                NaN               NaN
# 9  2018                                NaN               NaN
#
#                                                 Cast                Genre
# 0  Genevieve NnajiNkem OwohPete EdochieKanayo O. ...                Drama
# 1     Patience Ozokwor Adunni AdeAkpororoBishop Imeh               Comedy
# 2  Toyin Abraham Rachael OkonkwoLasisi ElenuOmowu...                Ghost
# 3  Ufuoma McDermottOmoni OboliToyin AbrahamMike E...               Comedy
# 4  Chris AttohZainab Balogun Ini Dima-Okojie Ijeo...  Thriller drama film
# 5  Ayo MakunFolarin FalanaRamsey NouahOsas Ighoda...      Romantic comedy
# 6  Joke Silva Kate Henshaw Funke Akindele Folarin...         Comedy Drama
# 7  Rahama Sadau Kanayo O. Kanayo Adesua Etomi Ban...  Romantic drama film
# 8                                                NaN                  NaN
# 9                                                NaN                  NaN

# %% [markdown]
# ## Extract Data for 2019

# %%
# Define the URL
link = "https://en.wikipedia.org/wiki/List_of_Nigerian_films_of_2019"

df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

df = pd.concat([df1, df2, df3, df3], ignore_index=True)

# Create a Dataframe
df_2019 = df[['Title','Director','Cast']]

# Add the "Year" column with the year "2019" for all rows
df_2019.insert(0, "Year", 2019)

df_2019.head(10)
# Out:
#    Year Title Director Cast
# 0  2019   NaN      NaN  NaN
# 1  2019   NaN      NaN  NaN
# 2  2019   NaN      NaN  NaN
# 3  2019   NaN      NaN  NaN
# 4  2019   NaN      NaN  NaN
# 5  2019   NaN      NaN  NaN
# 6  2019   NaN      NaN  NaN
# 7  2019   NaN      NaN  NaN
# 8  2019   NaN      NaN  NaN
# 9  2019   NaN      NaN  NaN

# %% [markdown]
# ## Extract Data for 2020

# %%
# Define the URL
link = "https://en.wikipedia.org/wiki/List_of_Nigerian_films_of_2020"

df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

df = pd.concat([df1, df2, df3, df3], ignore_index=True)

# Create a Dataframe
df_2020 = df[['Title','Director','Cast','Genre']]

# Add the "Year" column with the year "2020" for all rows
df_2020.insert(0, "Year", 2020)

df_2020.head(10)
# Out:
#    Year                               Title            Director  \
# 0  2020                           Soft Work    Darasen Richards
# 1  2020  Fate of Alakada: The Party Planner        Kayode Kasum
# 2  2020                             Kakanfo    David Dida Tella
# 3  2020               This Lady Called Life        Kayode Kasum
# 4  2020                  Rise of the Saints  Samuel O . Olateru
# 5  2020                            Lemonade      Lummie Edevibe
# 6  2020                Lagos to Abuja Coach     Olamide Balogun
# 7  2020                            Citation      Kunle Afolayan
# 8  2020                              Ratnik      Dimeji Ajibola
# 9  2020       Rattlesnake: The Ahanna story        Ramsey Nouah
#
#                                                 Cast            Genre
# 0  Frank Donga Akin Lewis Shaffy Bello Sanni Mu’a...     Action drama
# 1               Toyin Abraham Mercy Eke Broda Shaggi    Action comedy
# 2               Bimbo Oshin Antar Laniyan Dele Odule  Adventure drama
# 3                           Bisola Aiyeola Efa Iwara            Drama
# 4             Deyemi Okanlawon Rachel Oniga Tina Mba            Drama
# 5  Kunle Remi Ayoola Ayolola Dino Melaye Linda Osifo            Drama
# 6        Akin Lewis Adunni Ade Tina Mba Maryam Booth            Drama
# 7  Temi Otedola Jimmy Jean-Lewis Kunle Afolayan J...            Drama
# 8  Osas Ighodaro Bolanle Ninalowo Adunni Ade Kari...  Science fiction
# 9    Stan Nze Osas Ighodaro Bucci Franklin Efa Iwara      Crime drama

# %% [markdown]
# ## Extract Data for 2021

# %%
# Define the URL
link = "https://en.wikipedia.org/wiki/List_of_Nigerian_films_of_2021"

df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

df = pd.concat([df1, df2, df3, df3], ignore_index=True)

# Create a Dataframe
df_2021 = df[['Title','Director','Cast','Genre']]

# Add the "Year" column with the year "2021" for all rows
df_2021.insert(0, "Year", 2021)

df_2021.head(10)
# Out:
#    Year              Title                    Director  \
# 0  2021         Prophetess            Niyi Akinmolayan
# 1  2021       Breaded Life              Biodun Stephen
# 2  2021            Eyimofe         Ari and Chuko Esiri
# 3  2021           The Wait                 Yemi Morafa
# 4  2021          Suga Suga                Richard Omos
# 5  2021               Mimi  Samuel ‘’Bigsam’’ Olatunji
# 6  2021           Lockdown                Moses Inwang
# 7  2021  My Village People            Niyi Akinmolayan
# 8  2021   The New Patriots                 Terry Ayebo
# 9  2021           Badamasi                Obi Emelonye
#
#                                                 Cast                   Genre
# 0  Toyin Abraham Lateef Adedimeji Muyiwa Ademola ...                  Comedy
# 1  Timini Egbuson Bimbo Ademoye Tina Mba Jide Kosoko         Romantic comedy
# 2  Jude Akuwudike Temi Ami-Williams Cynthia Ebiji...                     NaN
# 3  Nse Ikpe Etim Deyemi Okanlawon Jimmy Odukoya C...             Faith based
# 4   Taiwo Obileye Ayo Adesanya Tana Adelana Wole Ojo                  Comedy
# 5  Ali Baba Ireti Doyle Toyin Abraham Prince Jide...                     NaN
# 6  Omotola Jalade-Ekeinde Tony Umez Charles Awuru...  Psychological thriller
# 7  Bovi Ugboma Nkem Owoh Amaechi Muonagor Charles...                  Comedy
# 8  Akin Lewis Dele Odule Bimbo Oshin Taiwo Ibikun...      Political thriller
# 9  Enyinna Nwigwe Charles Inojie Sani Danja Yakub...                  Biopic

# %% [markdown]
# ## Extract Data for 2022

# %%
# Define the URL
link = "https://en.wikipedia.org/wiki/List_of_Nigerian_films_of_2022"

df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

df = pd.concat([df1, df2, df3, df3], ignore_index=True)

# Create a Dataframe
df_2022 = df[['Title','Director','Cast','Genre']]

# Add the "Year" column with the year "2022" for all rows
df_2022.insert(0, "Year", 2022)

df_2022.head(10)
# Out:
#    Year                         Title                                Director  \
# 0  2022  King of Thieves (Ogundabede)  Adebayo Tijani and Tope Adebayo Salami
# 1  2022            The Blood Covenant                             Fiyin Gambo
# 2  2022                           NaN                                     NaN
# 3  2022                           NaN                                     NaN
# 4  2022                  Tiger's Tail                             Uyoyou Adia
# 5  2022                       Hey You                             Uyoyou Adia
# 6  2022                         Sista                          Biodun Stephen
# 7  2022                  The Set Up 2                               Naz Onuzo
# 8  2022                           NaN                                     NaN
# 9  2022                     Anikulapo                          Kunle Afolayan
#
#                                                 Cast            Genre
# 0  Toyin AbrahamFemi Adebayo SalamiOdunlade Adeko...            Drama
# 1  Tobi BakreShawn FaquaUzor ArukweErica Nlewedim...              NaN
# 2                                                NaN              NaN
# 3                                                NaN              NaN
# 4  Alexx EkuboNatacha AkideAkintoba Adeoluwa Zubb...              NaN
# 5  Timini EgbusonEfe Irele Rotimi Salami Stan Nze...  Romantic comedy
# 6    Kehinde Bankole Bisola Aiyeola Deyemi Okanlawon              NaN
# 7            Adesua EtomiNancy Isime Kehinde Bankole              NaN
# 8                                                NaN              NaN
# 9                                                NaN              NaN

# %% [markdown]
# ## Merge the datasets

# %%
new_dataset_1992_2022 = pd.concat([df_1992, df_1997, df_1998, df_2001, df_2002, df_2003, df_2004, df_2005, df_2006, df_2007, df_2008, df_2010, df_2011, df_2012, df_2013, df_2014, df_2015, df_2016, df_2017, df_2018, df_2020, df_2021, df_2022], ignore_index=True)

# %% [markdown]
# ### Sort the merged DataFrame by the "Year" column

# %%
new_dataset_1992_2022 = new_dataset_1992_2022.sort_values(by="Year")

# %% [markdown]
# ### Drop rows with NaN in all columns

# %%
columns_to_check = new_dataset_1992_2022.columns.difference(["Year"])
new_dataset_1992_2022 = new_dataset_1992_2022.dropna(subset=columns_to_check, how='all')

# %% [markdown]
# ### Reset the index

# %%
new_dataset_1992_2022 = new_dataset_1992_2022.reset_index(drop=True)

# %% [markdown]
# ## Save Data to New File

# %%
new_dataset_1992_2022.to_csv('nigerian_movies_dataset_1992_2022.csv', index=False)
